# %%
import data_wash
from data_wash import save_cleaned_data
import pandas as pd
import json
import pandas as pd
import os
import re
from typing import List, Dict, Union
from datetime import datetime
import argparse
import io
import requests
import time
api_key='8d8887938848e63233b090f373ad959b'#高德地图的API密钥

# %%
df1= pd.read_json('../washdata/成都-重庆-嵌入式_20260101_232152/cleaned_jobs_20260101_232152.json')
df2= pd.read_json('../washdata/深圳-嵌入式_20260102_000303/cleaned_jobs_20260102_000303.json')
df = pd.concat([df1, df2], ignore_index=True)
df= df.drop_duplicates(subset=['jobid'], keep='first')

# %%
def city_clean(city, detail_address):
    """
    归一化城市字段为:xx市-xx区 或 xx市-xx市(县级市)
    Args:
        city (str): 城市名称
        detail_address (str): 详细地址
    Returns:
        str or None: 归一化后的城市字段,格式为'第一级-第二级',找不到则返回None
    """
    # 处理空值情况
    if not detail_address or not isinstance(detail_address, str):
        return None
    
    # 检查city是否已经是合适的格式
    # 合适的格式应该是:xx市-xx区/县/市,不能是:武汉-江夏区(缺少"市")
    if city and '-' in city:
        parts = city.split('-')
        # 检查第一部分是否以"市"结尾
        if len(parts) == 2 and parts[0].endswith('市'):
            return city
        # 否则继续处理
    
    # 解析详细地址,提取省级行政单位后的两级
    # 使用更精确的匹配:确保"市"是第一级行政单位的结尾
    # 匹配:省份(可选) + 地级市(必须以市/州/盟结尾) + 区县(必须以区/县/市等结尾)
    pattern = r'(?:.*?(?:省|自治区|特别行政区))?\s*([^省]+?(?:市|州|盟|地区))\s*([^市州盟地区]+?(?:区|县|市|旗|自治县|自治旗))'
    
    match = re.search(pattern, detail_address)
    
    if not match:
        return None
    
    city_level = match.group(1).strip()
    district_level = match.group(2).strip()
    
    # 处理直辖市的情况(北京、上海、天津、重庆)
    direct_cities = ['北京', '上海', '天津', '重庆']
    for dc in direct_cities:
        if dc in city_level:
            # 直辖市格式:北京市-朝阳区
            return f"{city_level}-{district_level}"
    
    # 返回规范格式
    return f"{city_level}-{district_level}"

# %%
print(city_clean("昆山", "江苏省苏州市昆山市玉山镇景欣苑小区8栋"))
print(city_clean("成都市-双流区", "四川省成都市双流区成都芯谷产业园区A9地块1号楼"))
print(city_clean("武汉-江夏区", "湖北省武汉市江夏区江夏区经济开发区庙山街道阳光三路"))
print(city_clean("成都", "四川省成都市双流区成都芯谷产业园区A9地块1号楼"))
print(city_clean("成都", "四川省成都市双流区成都芯谷产业园区A9地块1号楼"))
# Out:
# 苏州市-昆山市
# 成都市-双流区
# 武汉市-江夏区
# 成都市-双流区

# %%
df['城市'] = df.apply(lambda x: city_clean(x['城市'], x['详细地址']), axis=1)

# %%
def check():
    return df

# %%
check()
# Out:
#                                                   公司标签                 职位名称  \
# 0    [省级工程技术研究中心, 拥有节能环保技术, 国有企业, 央企子公司, 高新技术企业, 创新...  嵌入式软件工程师-成都(J10266)
# 1                                                   []      嵌入式软件开发4（工作地武汉）
# 2    [省级工程技术研究中心, 拥有节能环保技术, 国有企业, 央企子公司, 高新技术企业, 创新...  嵌入式硬件工程师-成都(J10265)
# 3    [小巨人企业, 高新技术企业, 创新型中小企业, 专精特新企业, 经营年限全国同行前5%, ...  嵌入式软件工程师（地点：上海）（成都）
# 4                                            [大学生就业贡献]        plc嵌入式软件开发工程师
# ..                                                 ...                  ...
# 967  [拥有节能环保技术, 知名品牌供应商, 上市企业供应商, 港澳台投资企业, 高新技术企业, ...   后端开发实习生-TikTok智能创作
# 968  [国企供应商, 知名品牌供应商, A股上市, 高新技术企业, 小巨人企业, 省级工程技术研究...             硬件工程师实习生
# 969  [大学生就业贡献, 高新技术企业, 科技型中小企业, 经营年限全国同行前10%, 战略投资融...     硬件电路设计工程师（机器人方向）
# 970                                          [大学生就业贡献]           物联网软件测试实习生
# 971  [省级工程技术研究中心, 拥有节能环保技术, 港澳台投资企业, 省级企业技术中心, 经营年限...          软件测试实习生（深圳）
#
#                   公司名称                      经纬度      jobid           薪资  \
# 0              中科芯集成电路     [0.000000, 0.000000]  167102488       1.2-2万
# 1    中国船舶集团有限公司第七一〇研究所  [30.390866, 114.348331]  168094926     1.5-1.6万
# 2              中科芯集成电路     [0.000000, 0.000000]  167102579       1.2-2万
# 3              苏州顺芯半导体   [31.186858, 121.43842]  161144177     1.4-2.2万
# 4           成都至诚云连通信科技  [30.685917, 104.150751]  164308469         5-7千
# ..                 ...                      ...        ...          ...
# 967               抖音视界  [22.534708, 113.953619]  162032367        8千-1万
# 968         碧兴物联科技（深圳）   [22.597453, 113.87781]  164502376       200元/天
# 969           深圳市天博智科技  [22.566159, 113.952857]  167216522  8千-1.6万·15薪
# 970           深圳市征逸涂科技  [22.665874, 114.074662]  169932314   7.5-9千·14薪
# 971           茂佳科技（广东）   [22.57493, 113.934973]  166201077         2-4千
#
#           城市 学历要求     经验要求  公司性质             行业           发布时间  薪资下限(k)  \
# 0    成都市-双流区   硕士  在校生/应届生    国企  电子技术/半导体/集成电路  1760956110000     12.0
# 1    武汉市-江夏区   硕士  在校生/应届生  事业单位          学术/科研  1765216541000     15.0
# 2    成都市-双流区   硕士  在校生/应届生    国企  电子技术/半导体/集成电路  1760956109000     12.0
# 3    上海市-徐汇区   本科  在校生/应届生    民营  电子技术/半导体/集成电路  1767085522000     14.0
# 4    成都市-成华区   大专     无需经验    民营     通信/电信/网络设备  1767171929000      5.0
# ..       ...  ...      ...   ...            ...            ...      ...
# 967  深圳市-南山区   本科     无需经验    民营       互联网/电子商务  1767233099000      8.0
# 968  深圳市-宝安区   本科  在校生/应届生    民营             环保  1764578515000      4.4
# 969  深圳市-南山区   大专    1年及以上  创业公司          计算机软件  1767099101000      6.4
# 970  深圳市-龙岗区   大专     无需经验    民营          计算机软件  1766415442000      6.4
# 971  深圳市-南山区   本科     无需经验    民营  电子技术/半导体/集成电路  1767170912000      2.0
#
#      薪资上限(k)  平均薪资(k)   省份   区域                                 详细地址  学历等级  \
# 0       20.0     16.0  四川省  成都市             四川省成都市双流区成都芯谷产业园区A9地块1号楼   5.0
# 1       16.0     15.5  湖北省  江夏区            湖北省武汉市江夏区江夏区经济开发区庙山街道阳光三路   5.0
# 2       20.0     16.0  四川省  成都市             四川省成都市双流区成都芯谷产业园区A9地块1号楼   5.0
# 3       22.0     18.0  上海市  徐汇区  上海市徐汇区徐家汇街道华谊兄弟时尚(上海)文化传媒有限公司上海电影广场   4.0
# 4        7.0      6.0  四川省  成华区               四川省成都市成华区二仙桥街道成华大道十里店路   3.0
# ..       ...      ...  ...  ...                                  ...   ...
# 967     10.0      9.0  广东省  南山区                   广东省深圳市南山区粤海街道安居南馨苑   4.0
# 968      4.4      4.4  广东省  宝安区           广东省深圳市宝安区西乡街道凤凰岗北一巷22号凤凰岗村   4.0
# 969     12.8      9.6  广东省  南山区                广东省深圳市南山区西丽街道茶光综合楼裕馨楼   3.0
# 970      7.7      7.1  广东省  龙岗区                  广东省深圳市龙岗区坂田街道岗头科技公园   3.0
# 971      4.0      3.0  广东省  南山区              广东省深圳市南山区西丽街道打石一路中兴人才公寓   4.0
#
#      经验年限
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ..    ...
# 967     0
# 968     0
# 969     1
# 970     0
# 971     0
#
# [972 rows x 20 columns]

# %%
save_cleaned_data(df)
# Out:
# 数据将保存到: C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata
# 清洗结果子目录: C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata\cleaned_jobs_20260102_152252
# ✓ JSON文件已保存: cleaned_jobs_20260102_152252.json
# ✓ CSV文件已保存: cleaned_jobs_20260102_152252.csv
# ✗ Excel保存失败: No module named 'openpyxl'
#
# ✓ 最新版本已保存为 'cleaned_jobs_latest.*'（位于 C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata）
# ✓ 统计报告已保存: data_stats_20260102_152252.txt
#
# ==================================================
# 所有文件保存完成！共 972 条记录
# 保存路径（子目录）: C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata\cleaned_jobs_20260102_152252
# 主目录中的最新文件: C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata
# ==================================================
# {'json': 'C:\\Users\\Buer_vakabauta\\Desktop\\Course\\data_analysis\\src\\washdata\\cleaned_jobs_20260102_152252\\cleaned_jobs_20260102_152252.json',
#  'csv': 'C:\\Users\\Buer_vakabauta\\Desktop\\Course\\data_analysis\\src\\washdata\\cleaned_jobs_20260102_152252\\cleaned_jobs_20260102_152252.csv',
#  'excel': None}

# %%
df= pd.read_json('../washdata/cleaned_jobs_latest.json')

# %%
def coord_clean(coordinate, detail_address):
    """
    如果原始坐标为空或0,调用高德api通过详细地址获取经纬度
    Args:
        coordinate (str): 原始坐标字符串
        detail_address (str): 详细地址
    Returns:
        tuple: [经度, 纬度] 
    """
    if coordinate and isinstance(coordinate, list) and len(coordinate)== 2:
        if int(float(coordinate[0])) and int(float(coordinate[1])):
            return coordinate
    url=f'https://restapi.amap.com/v3/geocode/geo?key={api_key}&address={detail_address}'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if data['status'] == '1' and data['geocodes']:
            location = data['geocodes'][0]['location']
            longitude, latitude = map(float, location.split(','))
            time.sleep(0.4)#延时等待,避免频率过高
            print(f"获取坐标中...")
            return [latitude,longitude]
    return [None, None]

# %%
df['经纬度'] = df.apply(lambda x: coord_clean(x['经纬度'], x['详细地址']), axis=1)
# Out:
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...
# 获取坐标中...

# %%
save_cleaned_data(df)
# Out:
# 数据将保存到: C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata
# 清洗结果子目录: C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata\cleaned_jobs_20260102_162719
# ✓ JSON文件已保存: cleaned_jobs_20260102_162719.json
# ✓ CSV文件已保存: cleaned_jobs_20260102_162719.csv
# ✗ Excel保存失败: No module named 'openpyxl'
#
# ✓ 最新版本已保存为 'cleaned_jobs_latest.*'（位于 C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata）
# ✓ 统计报告已保存: data_stats_20260102_162719.txt
#
# ==================================================
# 所有文件保存完成！共 972 条记录
# 保存路径（子目录）: C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata\cleaned_jobs_20260102_162719
# 主目录中的最新文件: C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\washdata
# ==================================================
# {'json': 'C:\\Users\\Buer_vakabauta\\Desktop\\Course\\data_analysis\\src\\washdata\\cleaned_jobs_20260102_162719\\cleaned_jobs_20260102_162719.json',
#  'csv': 'C:\\Users\\Buer_vakabauta\\Desktop\\Course\\data_analysis\\src\\washdata\\cleaned_jobs_20260102_162719\\cleaned_jobs_20260102_162719.csv',
#  'excel': None}
