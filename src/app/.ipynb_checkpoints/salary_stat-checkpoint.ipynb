# %% [markdown]
# ### 1. 行业薪资水平分布
#
# 分析“钱”景是数据挖掘中最直观的部分。
#
# - **薪资直方图与核密度估计 (KDE):** 统计 `平均薪资(k)` 的分布情况，观察薪资主要集中在哪个区间（比如 10k-15k 还是 20k-30k）。
#
# - **薪资箱线图 (Boxplot):** 按 `学历要求` 或 `公司性质` 分组，查看不同群体的薪资中位数、最大/最小值以及离群值（高薪岗位）。
#
# - **分析价值：** 揭示学历是否真的能带来显著的溢价。

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# 设置中文字体和样式
matplotlib.rcParams['font.sans-serif'] = ['SimHei', 'DejaVu Sans']
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
#数据来源
df = pd.read_csv('../washdata/cleaned_jobs_latest.csv')

# %%
#创建分析器
analyzer = SalaryAnalyzer(df)
# Out:
# 总数据: 337 条
# 有效薪资数据: 332 条
# 数据有效率: 98.5%

# %%
#基础数据统计
analyzer.basic_statistics()
# Out:
# ============================================================
# 薪资基础统计
# ============================================================
#
# 平均薪资: 10.35k
# 中位数薪资: 8.90k
# 标准差: 5.85k
# 最低薪资: 1.10k
# 最高薪资: 30.00k
#
# 25%分位数: 6.00k
# 75%分位数: 14.00k
#
# 薪资区间分布:
# 薪资区间
# 0-5k       49
# 5-10k     152
# 10-15k     58
# 15-20k     47
# 20-30k     26
# 30-50k      0
# 50k+        0
# Name: count, dtype: int64
# count    332.000000
# mean      10.347590
# std        5.848678
# min        1.100000
# 25%        6.000000
# 50%        8.900000
# 75%       14.000000
# max       30.000000
# Name: 平均薪资(k), dtype: float64

# %%
#薪资分布图
analyzer.plot_salary_distribution()
# Out:
# ✓ 薪资分布图已保存: ../output/salary_distribution.png

# %%
#学历--薪资箱线图
analyzer.plot_salary_by_education()
# Out:
# C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\app\salary_stat.py:193: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\app\salary_stat.py:215: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(
# ✓ 学历薪资分析图已保存: ../output/salary_by_education.png
# ============================================================
# 学历与薪资统计分析
# ============================================================
#
# 大专:
#   样本数: 88
#   平均薪资: 7.08k
#   中位数: 6.85k
#   标准差: 2.21k
#   最高薪资: 15.00k
#
# 本科:
#   样本数: 188
#   平均薪资: 10.07k
#   中位数: 8.50k
#   标准差: 6.00k
#   最高薪资: 30.00k
#
# 硕士:
#   样本数: 54
#   平均薪资: 16.76k
#   中位数: 15.50k
#   标准差: 4.27k
#   最高薪资: 30.00k

# %%
#公司性质与薪资
analyzer.plot_salary_by_company_type()
# Out:
# C:\Users\Buer_vakabauta\Desktop\Course\data_analysis\src\app\salary_stat.py:270: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
# ✓ 公司性质薪资分析图已保存: ../output/salary_by_company_type.png
# ============================================================
# 公司性质与薪资统计
# ============================================================
#           mean  median  count
# 公司性质
# 事业单位  15.81500   15.50     20
# 已上市   14.01600   12.50     25
# 国企    12.21875   11.50     16
# 民营     9.40000    7.45    258

# %%
#学历溢价分析
analyzer.comprehensive_analysis()
# Out:
# ============================================================
# 学历溢价效应分析
# ============================================================
#
# 以大专薪资(7.17k)为基准:
#   本科: 9.47k (溢价 +32.2%)
#   硕士: 16.90k (溢价 +135.7%)
# 学历要求
# 大专     7.167742
# 本科     9.474825
# 硕士    16.895745
# Name: 平均薪资(k), dtype: float64
